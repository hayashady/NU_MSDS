# %% [markdown]
# #### Imports

# %%
import pandas as pd

# %% [markdown]
# #### Read asset price data

# %%
data = pd.read_csv('/Users/dylanhayashi/Desktop/Northwestern/590 - Thesis Research/assets_m6.csv')

timeseries = data.pivot_table(index='date',columns='symbol',values='price')

display(timeseries)
# Out:
# symbol         ABBV      ACN     AEP      AIZ     ALLE     AMAT      AMP  \
# date
# 2022/01/31  131.870  348.301  86.601  149.851  120.808  136.910  298.157
# 2022/02/01  131.976  348.143  84.637  148.613  118.120  137.337  301.871
# 2022/02/02  133.537  354.103  86.102  150.323  118.298  139.467  306.877
# 2022/02/03  135.570  340.391  86.400  149.154  114.292  135.256  298.099
# 2022/02/04  135.492  342.312  85.422  150.401  117.382  134.324  301.871
# ...             ...      ...     ...      ...      ...      ...      ...
# 2023/02/13  153.730  288.350  91.090  133.570  119.920  116.530  355.330
# 2023/02/14  152.590  284.770  90.480  130.250  119.860  118.440  352.740
# 2023/02/15  151.060  287.650  90.920  131.950  121.580  119.460  350.300
# 2023/02/16  149.530  281.220  90.700  132.940  118.750  115.390  349.470
# 2023/02/17  151.310  277.050  92.410  132.410  118.600  115.440  351.480
#
# symbol         AMZN      AVB      AVY  ...     XLC     XLE     XLF      XLI  \
# ...
