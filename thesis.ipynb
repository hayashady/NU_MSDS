# %%
import pandas as pd
import plotly.express as px
import yfinance as yf

# %%
spy = yf.Ticker('SPY')

spy_data = spy.history(start='1990-01-01',end='2023-04-28')

display(spy_data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1993-01-29 00:00:00-05:00   25.140211   25.140211   25.015135   25.122343
# 1993-02-01 00:00:00-05:00   25.140210   25.301022   25.140210   25.301022
# 1993-02-02 00:00:00-05:00   25.283154   25.372494   25.229550   25.354626
# 1993-02-03 00:00:00-05:00   25.390370   25.640522   25.372503   25.622654
# 1993-02-04 00:00:00-05:00   25.711994   25.783466   25.426107   25.729862
# ...                               ...         ...         ...         ...
# 2023-04-21 00:00:00-04:00  412.190002  412.679993  410.170013  412.200012
# 2023-04-24 00:00:00-04:00  411.989990  413.070007  410.600006  412.630005
# 2023-04-25 00:00:00-04:00  410.579987  411.160004  406.019989  406.079987
# 2023-04-26 00:00:00-04:00  406.720001  407.839996  403.779999  404.359985
# 2023-04-27 00:00:00-04:00  407.000000  412.690002  406.739990  412.410004
#
# ...

# %%
display(px.line(spy_data.loc[:,['Open','High','Low','Close']]))
