# %%
import pandas as pd
import numpy as np
import os
import string
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import random
from dataclasses import dataclass
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
import gensim
from gensim.models import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.manifold import TSNE
import scipy.cluster.hierarchy
from IPython.display import display, HTML
from typing import List, Callable, Dict
from nltk.corpus import stopwords
import re

# %%
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %% [markdown]
# #### Import Data

# %%
data = pd.read_csv('/Users/dylanhayashi/Desktop/Northwestern/MSDS_453_Public/MSDS453_ClassCorpus/MSDS453_QA_20220906.csv')

# %% [markdown]
# #### Data Wrangling

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))

# %%
def nlp_transformations(df):
    """
    Apply NLP transformations to a pandas DataFrame.
    Parameters: df (DataFrame): Input dataframe with a column named 'Text'.
    Returns: DataFrame: A new dataframe with added columns for each NLP transformation.
    """
    df['Tokens'] = df['Text'].apply(word_tokenize)
    df['Normalized'] = df['Tokens'].apply(lambda x: [word.lower() for word in x])
    df['Lemmatized'] = df['Normalized'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
    df['No_Stop_Words'] = df['Lemmatized'].apply(lambda x: [word for word in x if word not in stop_words])
    df['Cleaned'] = df['No_Stop_Words'].apply(lambda x: [re.sub(r'[^a-zA-Z]', '', word) for word in x])
    df['Cleaned'] = df['Cleaned'].apply(lambda x: [word for word in x if word != ''])
    df['wrangle_one'] = df['Normalized']
    df['wrangle_two'] = df['No_Stop_Words']
    df['wrangle_three'] = df['Cleaned']
    return df

# %%
pd.set_option('display.max_rows',None)

# %%
wrangled_data = nlp_transformations(data).sort_values('Genre of Movie')
wrangled_data
# Out:
#      Doc_ID                  DSI_Title  \
# 0       160              ARE_Doc1_Taxi
# 116      46    KCM_Doc7_AngelHasFallen
# 115      45    KCM_Doc6_AngelHasFallen
# 114      44    KCM_Doc5_AngelHasFallen
# 113      43    KCM_Doc4_AngelHasFallen
# 112      42    KCM_Doc3_AngelHasFallen
# 111      41    KCM_Doc2_AngelHasFallen
# 110      40    KCM_Doc1_AngelHasFallen
# 117      47    KCM_Doc8_AngelHasFallen
# 198      88         MGB_Doc9_Inception
# 78      128       SDT_Doc9_NoTimeToDie
# 77      127       SDT_Doc8_NoTimeToDie
# 76      126       SDT_Doc7_NoTimeToDie
# 75      125       SDT_Doc6_NoTimeToDie
# 74      124       SDT_Doc5_NoTimeToDie
# 73      123       SDT_Doc4_NoTimeToDie
# 72      122       SDT_Doc3_NoTimeToDie
# 79      129      SDT_Doc10_NoTimeToDie
# 118      48    KCM_Doc9_AngelHasFallen
# 119      49   KCM_Doc10_AngelHasFallen
# 180       0             GGS_Doc1_Taken
# 197      87         MGB_Doc8_Inception
# 196      86         MGB_Doc7_Inception
# 195      85         MGB_Doc6_Inception
# 194      84         MGB_Doc5_Inception
# 193      83         MGB_Doc4_Inception
# 192      82         MGB_Doc3_Inception
# 191      81         MGB_Doc2_Inception
# 190      80         MGB_Doc1_Inception
# 189       9            GGS_Doc10_Taken
# 188       8             GGS_Doc9_Taken
# 187       7             GGS_Doc8_Taken
# 186       6             GGS_Doc7_Taken
# 185       5             GGS_Doc6_Taken
# 184       4             GGS_Doc5_Taken
# 183       3             GGS_Doc4_Taken
# 182       2             GGS_Doc3_Taken
# 181       1             GGS_Doc2_Taken
# 71      121       SDT_Doc2_NoTimeToDie
# 70      120       SDT_Doc1_NoTimeToDie
# 199      89        MGB_Doc10_Inception
# 1       161              ARE_Doc2_Taxi
# 2       162              ARE_Doc3_Taxi
# 3       163              ARE_Doc4_Taxi
# 4       164              ARE_Doc5_Taxi
# 5       165              ARE_Doc6_Taxi
# 6       166              ARE_Doc7_Taxi
# 7       167              ARE_Doc8_Taxi
# 8       168              ARE_Doc9_Taxi
# 9       169             ARE_Doc10_Taxi
# 120      20    JDB_Doc01_DespicableMe3
# 148      78       DWM_Doc9_TheLostCity
# 149      79      DWM_Doc10_TheLostCity
# 89      139    DWB_Doc10_LegallyBlonde
# 88      138     DWB_Doc9_LegallyBlonde
# 83      133     DWB_Doc4_LegallyBlonde
# 86      136     DWB_Doc7_LegallyBlonde
# 85      135     DWB_Doc6_LegallyBlonde
# 84      134     DWB_Doc5_LegallyBlonde
# 147      77       DWM_Doc8_TheLostCity
# 82      132     DWB_Doc3_LegallyBlonde
# 87      137     DWB_Doc8_LegallyBlonde
# 146      76       DWM_Doc7_TheLostCity
# 141      71       DWM_Doc2_TheLostCity
# 144      74       DWM_Doc5_TheLostCity
# 143      73       DWM_Doc4_TheLostCity
# 142      72       DWM_Doc3_TheLostCity
# 81      131     DWB_Doc2_LegallyBlonde
# 140      70       DWM_Doc1_TheLostCity
# 129      29    JDB_Doc10_DespicableMe3
# 128      28    JDB_Doc09_DespicableMe3
# 127      27    JDB_Doc08_DespicableMe3
# 126      26    JDB_Doc07_DespicableMe3
# 125      25    JDB_Doc06_DespicableMe3
# 124      24    JDB_Doc05_DespicableMe3
# 123      23    JDB_Doc04_DespicableMe3
# 122      22    JDB_Doc03_DespicableMe3
# 145      75       DWM_Doc6_TheLostCity
# 121      21    JDB_Doc02_DespicableMe3
# 80      130     DWB_Doc1_LegallyBlonde
# 57      147   ARB_Doc8_HolmesAndWatson
# 65       35      PYC_Doc6_DirtyGrandpa
# 64       34      PYC_Doc5_DirtyGrandpa
# 63       33      PYC_Doc4_DirtyGrandpa
# 62       32      PYC_Doc3_DirtyGrandpa
# 61       31      PYC_Doc2_DirtyGrandpa
# 60       30      PYC_Doc1_DirtyGrandpa
# 59      149  ARB_Doc10_HolmesAndWatson
# 58      148   ARB_Doc9_HolmesAndWatson
# 66       36      PYC_Doc7_DirtyGrandpa
# 67       37      PYC_Doc8_DirtyGrandpa
# 69       39     PYC_Doc10_DirtyGrandpa
# 56      146   ARB_Doc7_HolmesAndWatson
# 55      145   ARB_Doc6_HolmesAndWatson
# 54      144   ARB_Doc5_HolmesAndWatson
# 53      143   ARB_Doc4_HolmesAndWatson
# 52      142   ARB_Doc3_HolmesAndWatson
# 51      141   ARB_Doc2_HolmesAndWatson
# 50      140   ARB_Doc1_HolmesAndWatson
# 68       38      PYC_Doc9_DirtyGrandpa
# 17      187                HLU_Doc8_US
# 160      90      JLG_Doc1_DragMeToHell
# 161      91      JLG_Doc2_DragMeToHell
# 16      186                HLU_Doc7_US
# 15      185                HLU_Doc6_US
# 14      184                HLU_Doc5_US
# 13      183                HLU_Doc4_US
# 12      182                HLU_Doc3_US
# 11      181                HLU_Doc2_US
# 10      180                HLU_Doc1_US
# 169      99     JLG_Doc10_DragMeToHell
# 168      98      JLG_Doc9_DragMeToHell
# 167      97      JLG_Doc8_DragMeToHell
# 166      96      JLG_Doc7_DragMeToHell
# 165      95      JLG_Doc6_DragMeToHell
# 164      94      JLG_Doc5_DragMeToHell
# 163      93      JLG_Doc4_DragMeToHell
# 162      92      JLG_Doc3_DragMeToHell
# 18      188                HLU_Doc9_US
# 40      100             JMI_Doc1_Fresh
# 41      101             JMI_Doc2_Fresh
# 20      170      DKX_Doc1_ItChapterTwo
# 97       67      KKN_Doc8_ToxicAvenger
# 96       66      KKN_Doc7_ToxicAvenger
# 95       65      KKN_Doc6_ToxicAvenger
# 94       64      KKN_Doc5_ToxicAvenger
# 93       63      KKN_Doc4_ToxicAvenger
# 92       62      KKN_Doc3_ToxicAvenger
# 91       61      KKN_Doc2_ToxicAvenger
# 98       68      KKN_Doc9_ToxicAvenger
# 90       60      KKN_Doc1_ToxicAvenger
# 48      108             JMI_Doc9_Fresh
# 47      107             JMI_Doc8_Fresh
# 46      106             JMI_Doc7_Fresh
# 45      105             JMI_Doc6_Fresh
# 44      104             JMI_Doc5_Fresh
# 43      103             JMI_Doc4_Fresh
# 42      102             JMI_Doc3_Fresh
# 49      109            JMI_Doc10_Fresh
# 19      189               HLU_Doc10_US
# 29      179     DKX_Doc10_ItChapterTwo
# 99       69     KKN_Doc10_ToxicAvenger
# 27      177      DKX_Doc8_ItChapterTwo
# 26      176      DKX_Doc7_ItChapterTwo
# 25      175      DKX_Doc6_ItChapterTwo
# 28      178      DKX_Doc9_ItChapterTwo
# 23      173      DKX_Doc4_ItChapterTwo
# 22      172      DKX_Doc3_ItChapterTwo
# 21      171      DKX_Doc2_ItChapterTwo
# 24      174      DKX_Doc5_ItChapterTwo
# 179     199       JSA_Doc10_PitchBlack
# 172     192        JSA_Doc3_PitchBlack
# 173     193        JSA_Doc4_PitchBlack
# 174     194        JSA_Doc5_PitchBlack
# 175     195        JSA_Doc6_PitchBlack
# 176     196        JSA_Doc7_PitchBlack
# 177     197        JSA_Doc8_PitchBlack
# 178     198        JSA_Doc9_PitchBlack
# 30       10       DRN_Doc1_EQUILIBRIUM
# 34       14       DRN_Doc5_EQUILIBRIUM
# 32       12       DRN_Doc3_EQUILIBRIUM
# 33       13       DRN_Doc4_EQUILIBRIUM
# 171     191        JSA_Doc2_PitchBlack
# 35       15       DRN_Doc6_EQUILIBRIUM
# 36       16       DRN_Doc7_EQUILIBRIUM
# 37       17       DRN_Doc8_EQUILIBRIUM
# 38       18       DRN_Doc9_EQUILIBRIUM
# 39       19      DRN_Doc10_EQUILIBRIUM
# 31       11       DRN_Doc2_EQUILIBRIUM
# 109     119   RSV_Doc10_MinorityReport
# 108     118    RSV_Doc9_MinorityReport
# 131      51          JTG_Doc2_Oblivion
# 107     117    RSV_Doc8_MinorityReport
# 106     116    RSV_Doc7_MinorityReport
# 105     115    RSV_Doc6_MinorityReport
# 104     114    RSV_Doc5_MinorityReport
# 103     113    RSV_Doc4_MinorityReport
# 102     112    RSV_Doc3_MinorityReport
# 101     111    RSV_Doc2_MinorityReport
# 100     110    RSV_Doc1_MinorityReport
# 150     150            JLV_Doc1_Batman
# 151     151            JLV_Doc2_Batman
# 152     152            JLV_Doc3_Batman
# 153     153            JLV_Doc4_Batman
# 130      50          JTG_Doc1_Oblivion
# 154     154            JLV_Doc5_Batman
# 156     156            JLV_Doc7_Batman
# 157     157            JLV_Doc8_Batman
# 158     158            JLV_Doc9_Batman
# 159     159           JLV_Doc10_Batman
# 139      59         JTG_Doc10_Oblivion
# 138      58          JTG_Doc9_Oblivion
# 137      57          JTG_Doc8_Oblivion
# 136      56          JTG_Doc7_Oblivion
# 135      55          JTG_Doc6_Oblivion
# 134      54          JTG_Doc5_Oblivion
# 133      53          JTG_Doc4_Oblivion
# 132      52          JTG_Doc3_Oblivion
# 155     155            JLV_Doc6_Batman
# 170     190        JSA_Doc1_PitchBlack
#
#                                                   Text  \
# 0    Jimmy Fallon's big screen career may be over b...
# 116  Authorities take Secret Service agent Mike Ban...
# 115  American movie presidents can only make us wis...
# 114  No, you dont need to have seen Olympus Has F...
# 113  There is a certain mindless pleasure in the Fa...
# 112  Ric Roman Waughs Angel Has Fallen sees U.S. S...
# 111  \nWho ARE all these people?\n\nThat was what...
# 110  Boredom sets in long before the start of Angel...
# 117  Angel Has Fallen is what used to be called a B...
# 198  After reading all the amazing reviews and seei...
# 78   The new James Bond movie “No Time To Die” is t...
# 77   For those whose cinematic consciousness predat...
# 76   Let the mourning begin.  In No Time to Die, Ja...
# 75   No Time to Die, the latest and last appearance...
# 74   James Bond (Daniel Craig, in reportedly his la...
# 73   No Time to Die is an outstanding end to Daniel...
# 72   James Bond has saved the world two dozen times...
# 79   Daniel Craig makes his royal exit in "No Time ...
# 118  Any spy thriller character who hangs around lo...
# 119  Butler delivers a good performance as Banning ...
# 180  Liam Neeson flashes a telltale Harrison Ford s...
# 197  Unless you call this movie a masterpiece. Then...
# 196  You have this basic idea and the story, they a...
# 195  Inception makes the average moviegoer feel sma...
# 194  Inception is a movie that works outside our lo...
# 193  Inception has a problem that I cannot bear: th...
# 192  Only a small handful of directors have the abi...
# 191  Surrealism can appear to be ineffably bizarre,...
# 190  I'm nearly at a loss for words. Just when you ...
# 189  Liam Neeson was up forbut never got to playJ...
# 188  Any parent could relate to Bryan Mills (Liam N...
# 187  If there are any 24 fans who have wondered wha...
# 186  You can see that in the way the film portrays ...
# 185  Taken is the latest film from the French film-...
# 184  Taken: Action thriller. Starring Liam Neeson, ...
# 183  Takens greatest asset resides within the per...
# 182  Who knew Liam Neeson, the same highly regarded...
# 181  Maybe I was just in a really good mood when I ...
# 71   If there’s one consistency in the Daniel Craig...
# 70   Now he’s come to the end of his run, Daniel Cr...
# 199  A shame that this movie is rated so highly on ...
# 1    After getting nominated for "Chicago" and maki...
# 2    Queen Latifah handily walked away with the sho...
# 3    So Jimmy Fallon leaves ÒSaturday Night LiveÓ a...
# 4    TaxiÊcasts JimmyÊFallon as Officer Andy Washbu...
# 5    Jimmy Fallon needs to call Tina Fey and beg he...
# 6    How one likes "Taxi" has everything to do with...
# 7    ChicagoÕs Queen Latifah andÊSaturday Night Liv...
# 8    After five years of waiting, Belle Williams (Q...
# 9    On her first day as a taxi driver, the wild Be...
# 120  As former super-villain Gru (Steve Carell) tri...
# 148  There was a certain flavor of film that we use...
# 149  The Lost City is exactly what it says on the t...
# 89   Don't judge a book by it's cover. An old sayin...
# 88   I didn't go into "Legally Blonde" expecting to...
# 83   Reese Witherspoon is just 25 years old, but sh...
# 86   Written by Kirsten Smith and Karen McCullah Lu...
# 85   If her dazzling turns inÊElection, Freeway,Êan...
# 84   Legally Blonde, a hefty handful of funny jokes...
# 147  There are few things as uplifting as the embra...
# 82   Say all you will about the animated Dr. Aki Ro...
# 87   It's not that easy to simultaneously make fun ...
# 146  Channing Tatum plays himbos like Mozart wrote ...
# 141  In a setup and general vibe that reminded me o...
# 144  Once again, a comedy that relies on the gimmic...
# 143  Sandra Bullock recently announced that shed b...
# 142  Loretta Sage has an interesting past. She stud...
# 81   Legally BlondeÊis, of course, a pun on "legall...
# 140  Aaron and Adam Nees The Lost City is one of t...
# 129  Let's face it
#  Illumination Entertainment and ...
# 128  Once upon a time Gru (Steve Carrell) was a chr...
# 127  Unlike most films in Illuminations canon, the...
# 126  I never thought Id complain about a Despicabl...
# 125  At what point to film series and franchises be...
# 124  Im confident that the minions would gleefully...
# 123  Although Readers at IMDB.com and the critics a...
# 122  Lets start this by saying, me and my kids wor...
# 145  After being taken hostage, a romance-adventure...
# 121  Some animation features only have to answer on...
# 80   Newcomer Robert Luketic makes his feature film...
# 57   Etan Cohen didnât write Holmes & Watson as a...
# 65   Make no mistake about it, Robert De Niro is a ...
# 64   My hopes were high for “Dirty Grandpa,” simply...
# 63   Okay, I know what you all may be thinking, Dir...
# 62   2016's Dirty Grandpa was certainly a divisive ...
# 61   You're probably not going to read the whole th...
# 60   Dirty Grandpa has an 11% approval rating on Ro...
# 59   Maybe itâs just the holiday spirit, but I ca...
# 58   Finding out what went wrong with âHolmes and...
# 66   This is a very disturbing and difficult movie ...
# 67   On Jan. 22, “Dirty Grandpa” was unleashed on t...
# 69   When Robert De Niro receives his inevitable li...
# 56   One of the yearâs most critically shellacked...
# 55   Many distinguished actors have played Sherlock...
# 54   The start of Holmes & Watson is both cynical a...
# 53   A previously undiscovered short story shows wh...
# 52   There's a moment during the stunningly abysmal...
# 51   Out of some morbid curiosity, and perhaps a se...
# 50   Remember that scene in Step Brothers, when a s...
# 68   Humor, it must be acknowledged, is entirely su...
# 17   Few directorial debuts were as shattering as J...
# 160  In "Drag Me to Hell," Our Heroine Christine Br...
# 161  To properly (and fairly) access my experience ...
# 16   Is my own doppelgänger going to kill me if I d...
# 15   They say lightning doesn’t strike twice, but s...
# 14   Jordan Peele’s 2017 thriller Get Out turned on...
# 13   We can probably all agree that looking at your...
# 12   An idyllic vacation turns into a living nightm...
# 11   Lupita Nyong’o stars in Jordan Peele’s newest ...
# 10   For those of you uninterested in a deep dive i...
# 169  When I was in elementary school, we had a clas...
# 168  The title “Drag Me to Hell” offers both litera...
# 167  Oh no, not another PG-13 horror film! "But wai...
# 166  “Drag Me to Hell” finds Sam Raimi returning to...
# 165  On the way to the theater, I tell my buddy "Th...
# 164  From the intense opening scene to the stellar ...
# 163  For me, Drag Me to Hell was one of the ultimat...
# 162  In each of the two great movies opening this w...
# 18   Writer-director Jordan Peele’s 2017 Get Out wa...
# 40   Is Sebastian Stan the dullest actor working to...
# 41   The central idea of Fresh is either a blunt me...
# 20   Stephen King took 1,138 pages to tell the stor...
# 97   I have to force myself not to give this movie ...
# 96   The Toxic Avenger starts with a shot of the Ne...
# 95   I can say the most positive thing about The To...
# 94   The Toxic Avenger is an excellent and hilariou...
# 93   Toxic Avenger 21st Anniversary Ed. 2 Disc Set ...
# 92   I've never seen a Troma film before but I do r...
# 91   When I was a teenager, the only available plac...
# 98   Four crazed teenagers speed down the road in t...
# 90   This film believe or not is one of my favorate...
# 48   The opening credits of Fresh don't arrive unti...
# 47   If you saw Netflix's recent "The Tinder Swindl...
# 46   Mimi Caves debut feature Fresh sits in a tric...
# 45   Every now and then, a movie comes along that i...
# 44   Modern dating can make a girl feel like a real...
# 43   There is a line in horror, where the storytell...
# 42   Modern dating is banal and dehumanizing. The m...
# 49   No matter how many digital barricades we place...
# 19   I would love to be able to say that Jordan Pee...
# 29   In 2017 Stephen King adaptations took a seriou...
# 99   In the world of movies, many know of the main ...
# 27   When the seven far-flung members of the so-cal...
# 26   Nearly 90 years ago in Fritz Langs M, a singl...
# 25   At what point do scary things lose their power...
# 28   Its wretched, ugly, unseemly and serves no re...
# 23   Why isnt Pennywise the clown as terrifying in...
# 22   Guess whos back, back again
# IT Chapter One wa...
# 21   It Chapter One, or whatever we must call it si...
# 24   Its been twenty-seven years since the Losers...
# 179  Sometimes, you have to take a movie at face va...
# 172  It's sci-fi season once again, what with this ...
# 173  Packed with razzle-dazzle special effects and ...
# 174  Richard B. Riddick (Vin Diesel) cant seem to ...
# 175  WHAT'S IT ABOUT?\nA passenger spaceship is hit...
# 176  There are just no good aliens anymore. The tit...
# 177  Is it an active contempt for the audience, I h...
# 178  When a spaceship crash-lands on a planet of th...
# 30   A tedious rip-off sci-fi film, itching to be a...
# 34   I tried watching Equilibrium a few years ago, ...
# 32   Equilibrium is a movie in search of a plot. Wr...
# 33   Three Movie Buffs\nPatrick - Negative\n\nEquil...
# 171  No other movie opening thrills me more than a ...
# 35   What happens when The Matrix and Fahrenheit 45...
# 36   You tread on my dreams.\n\nBenjamin Franklin o...
# 37   Bale Bales on the Future\nOn one hand "Equilib...
# 38   A Constantly Racing Mind\nRobert Barbere\n\nIn...
# 39   Roger Ebert   Christian Bales\n"Equilibrium'' ...
# 31   Equilibrium doesn't so much invoke a feeling o...
# 109  What new hell is this? In the shallow, noisy a...
# 108  In Minority Report, a futuristic thriller set ...
# 131  "Oblivion" is a big sci-fi movie which takes a...
# 107  Set in the year 2054, Steven Spielberg's Minor...
# 106  Once again this year we are graced with a futu...
# 105  Minority Report , directed by Steven Spielberg...
# 104  Steven Spielberg's Minority Report is a busy f...
# 103  “Minority Report” is the most un-Spielberg fil...
# 102  In the year 2054, at the Department of Precrim...
# 101  In the movie it’s the future (2054) and we now...
# 100  Steven Spielberg’s Minority Report realizes th...
# 150   When Warner Brothers announced that they were...
# 151  IÕve watched few movies more than Batman to th...
# 152  Created 50 years ago as a comic book hero, the...
# 153  Occasionally laughable but mostly tinged with ...
# 130  Only recently, Tom Cruise looked as if he was ...
# 154  The theatrical release of Batman celebrates 30...
# 156  Critics adored Batman for its eccentric, Burto...
# 157  "A bad film with a capable director." One of t...
# 158  Despite representing his newfound status as a ...
# 159  Tim BurtonÕs generally well-regarded 1989 Batm...
# 139  Oblivion is a competently made sci-fi action...
# 138  Film genres have their boom years and their bu...
# 137  A sort of The Eternal Return played out in the...
# 136  Although Universals publicity department has ...
# 135  Oblivion looks marvelous, in the deliciously...
# 134  What do you need for the ultimate Tom Cruise v...
# 133  In Oblivion, Tom Cruise plays a post-apocaly...
# 132  Co-writer-director Joseph Kosinski (TRON: Leg...
# 155  As its trailer has already hinted, ÒBatmanÓ (c...
# 170  It's Vin Diesel week! Suddenly, this largely u...
#
#           Submission File Name     Student Name Genre of Movie  \
# 0                ARE_Doc1_Taxi              ARE         Action
# 116    KCM_Doc7_AngelHasFallen              KCM         Action
# 115    KCM_Doc6_AngelHasFallen              KCM         Action
# 114    KCM_Doc5_AngelHasFallen              KCM         Action
# 113    KCM_Doc4_AngelHasFallen              KCM         Action
# 112    KCM_Doc3_AngelHasFallen              KCM         Action
# 111    KCM_Doc2_AngelHasFallen              KCM         Action
# 110    KCM_Doc1_AngelHasFallen              KCM         Action
# 117    KCM_Doc8_AngelHasFallen              KCM         Action
# 198         MGB_Doc9_Inception              MGB         Action
# 78        SDT_Doc9_NoTimeToDie              SDT         Action
# 77        SDT_Doc8_NoTimeToDie              SDT         Action
# 76        SDT_Doc7_NoTimeToDie              SDT         Action
# 75        SDT_Doc6_NoTimeToDie              SDT         Action
# 74        SDT_Doc5_NoTimeToDie              SDT         Action
# 73        SDT_Doc4_NoTimeToDie              SDT         Action
# 72        SDT_Doc3_NoTimeToDie              SDT         Action
# 79       SDT_Doc10_NoTimeToDie              SDT         Action
# 118    KCM_Doc9_AngelHasFallen              KCM         Action
# 119   KCM_Doc10_AngelHasFallen              KCM         Action
# 180             GGS_Doc1_Taken  Gavyn Gallagher         Action
# 197         MGB_Doc8_Inception              MGB         Action
# 196         MGB_Doc7_Inception              MGB         Action
# 195         MGB_Doc6_Inception              MGB         Action
# 194         MGB_Doc5_Inception              MGB         Action
# 193         MGB_Doc4_Inception              MGB         Action
# 192         MGB_Doc3_Inception              MGB         Action
# 191         MGB_Doc2_Inception              MGB         Action
# 190         MGB_Doc1_Inception              MGB         Action
# 189            GGS_Doc10_Taken  Gavyn Gallagher         Action
# 188             GGS_Doc9_Taken  Gavyn Gallagher         Action
# 187             GGS_Doc8_Taken  Gavyn Gallagher         Action
# 186             GGS_Doc7_Taken  Gavyn Gallagher         Action
# 185             GGS_Doc6_Taken  Gavyn Gallagher         Action
# 184             GGS_Doc5_Taken  Gavyn Gallagher         Action
# 183             GGS_Doc4_Taken  Gavyn Gallagher         Action
# 182             GGS_Doc3_Taken  Gavyn Gallagher         Action
# 181             GGS_Doc2_Taken  Gavyn Gallagher         Action
# 71        SDT_Doc2_NoTimeToDie              SDT         Action
# 70        SDT_Doc1_NoTimeToDie              SDT         Action
# 199        MGB_Doc10_Inception              MGB         Action
# 1                ARE_Doc2_Taxi              ARE         Action
# 2                ARE_Doc3_Taxi              ARE         Action
# 3                ARE_Doc4_Taxi              ARE         Action
# 4                ARE_Doc5_Taxi              ARE         Action
# 5                ARE_Doc6_Taxi              ARE         Action
# 6                ARE_Doc7_Taxi              ARE         Action
# 7                ARE_Doc8_Taxi              ARE         Action
# 8                ARE_Doc9_Taxi              ARE         Action
# 9               ARE_Doc10_Taxi              ARE         Action
# 120    JDB_Doc01_DespicableMe3              JDB         Comedy
# 148       DWM_Doc9_TheLostCity              DWM         Comedy
# 149      DWM_Doc10_TheLostCity              DWM         Comedy
# 89     DWB_Doc10_LegallyBlonde              DWB         Comedy
# 88      DWB_Doc9_LegallyBlonde              DWB         Comedy
# 83      DWB_Doc4_LegallyBlonde              DWB         Comedy
# 86      DWB_Doc7_LegallyBlonde              DWB         Comedy
# 85      DWB_Doc6_LegallyBlonde              DWB         Comedy
# 84      DWB_Doc5_LegallyBlonde              DWB         Comedy
# 147       DWM_Doc8_TheLostCity              DWM         Comedy
# 82      DWB_Doc3_LegallyBlonde              DWB         Comedy
# 87      DWB_Doc8_LegallyBlonde              DWB         Comedy
# 146       DWM_Doc7_TheLostCity              DWM         Comedy
# 141       DWM_Doc2_TheLostCity              DWM         Comedy
# 144       DWM_Doc5_TheLostCity              DWM         Comedy
# 143       DWM_Doc4_TheLostCity              DWM         Comedy
# 142       DWM_Doc3_TheLostCity              DWM         Comedy
# 81      DWB_Doc2_LegallyBlonde              DWB         Comedy
# 140       DWM_Doc1_TheLostCity              DWM         Comedy
# 129    JDB_Doc10_DespicableMe3              JDB         Comedy
# 128    JDB_Doc09_DespicableMe3              JDB         Comedy
# 127    JDB_Doc08_DespicableMe3              JDB         Comedy
# 126    JDB_Doc07_DespicableMe3              JDB         Comedy
# 125    JDB_Doc06_DespicableMe3              JDB         Comedy
# 124    JDB_Doc05_DespicableMe3              JDB         Comedy
# 123    JDB_Doc04_DespicableMe3              JDB         Comedy
# 122    JDB_Doc03_DespicableMe3              JDB         Comedy
# 145       DWM_Doc6_TheLostCity              DWM         Comedy
# 121    JDB_Doc02_DespicableMe3              JDB         Comedy
# 80      DWB_Doc1_LegallyBlonde              DWB         Comedy
# 57    ARB_Doc8_HolmesAndWatson              ARB         Comedy
# 65       PYC_Doc6_DirtyGrandpa              PYC         Comedy
# 64       PYC_Doc5_DirtyGrandpa              PYC         Comedy
# 63       PYC_Doc4_DirtyGrandpa              PYC         Comedy
# 62       PYC_Doc3_DirtyGrandpa              PYC         Comedy
# 61       PYC_Doc2_DirtyGrandpa              PYC         Comedy
# 60       PYC_Doc1_DirtyGrandpa              PYC         Comedy
# 59   ARB_Doc10_HolmesAndWatson              ARB         Comedy
# 58    ARB_Doc9_HolmesAndWatson              ARB         Comedy
# 66       PYC_Doc7_DirtyGrandpa              PYC         Comedy
# 67       PYC_Doc8_DirtyGrandpa              PYC         Comedy
# 69      PYC_Doc10_DirtyGrandpa              PYC         Comedy
# 56    ARB_Doc7_HolmesAndWatson              ARB         Comedy
# 55    ARB_Doc6_HolmesAndWatson              ARB         Comedy
# 54    ARB_Doc5_HolmesAndWatson              ARB         Comedy
# 53    ARB_Doc4_HolmesAndWatson              ARB         Comedy
# 52    ARB_Doc3_HolmesAndWatson              ARB         Comedy
# 51    ARB_Doc2_HolmesAndWatson              ARB         Comedy
# 50    ARB_Doc1_HolmesAndWatson              ARB         Comedy
# 68       PYC_Doc9_DirtyGrandpa              PYC         Comedy
# 17                 HLU_Doc8_US              HLU         Horror
# 160      JLG_Doc1_DragMeToHell              JLG         Horror
# 161      JLG_Doc2_DragMeToHell              JLG         Horror
# 16                 HLU_Doc7_US              HLU         Horror
# 15                 HLU_Doc6_US              HLU         Horror
# 14                 HLU_Doc5_US              HLU         Horror
# 13                 HLU_Doc4_US              HLU         Horror
# 12                 HLU_Doc3_US              HLU         Horror
# 11                 HLU_Doc2_US              HLU         Horror
# 10                 HLU_Doc1_US              HLU         Horror
# 169     JLG_Doc10_DragMeToHell              JLG         Horror
# 168      JLG_Doc9_DragMeToHell              JLG         Horror
# 167      JLG_Doc8_DragMeToHell              JLG         Horror
# 166      JLG_Doc7_DragMeToHell              JLG         Horror
# 165      JLG_Doc6_DragMeToHell              JLG         Horror
# 164      JLG_Doc5_DragMeToHell              JLG         Horror
# 163      JLG_Doc4_DragMeToHell              JLG         Horror
# 162      JLG_Doc3_DragMeToHell              JLG         Horror
# 18                 HLU_Doc9_US              HLU         Horror
# 40              JMI_Doc1_Fresh              JMI         Horror
# 41              JMI_Doc2_Fresh              JMI         Horror
# 20       DKX_Doc1_ItChapterTwo              DKX         Horror
# 97       KKN_Doc8_ToxicAvenger       KerryKurcz         Horror
# 96       KKN_Doc7_ToxicAvenger       KerryKurcz         Horror
# 95       KKN_Doc6_ToxicAvenger       KerryKurcz         Horror
# 94       KKN_Doc5_ToxicAvenger       KerryKurcz         Horror
# 93       KKN_Doc4_ToxicAvenger       KerryKurcz         Horror
# 92       KKN_Doc3_ToxicAvenger       KerryKurcz         Horror
# 91       KKN_Doc2_ToxicAvenger       KerryKurcz         Horror
# 98       KKN_Doc9_ToxicAvenger       KerryKurcz         Horror
# 90       KKN_Doc1_ToxicAvenger       KerryKurcz         Horror
# 48              JMI_Doc9_Fresh              JMI         Horror
# 47              JMI_Doc8_Fresh              JMI         Horror
# 46              JMI_Doc7_Fresh              JMI         Horror
# 45              JMI_Doc6_Fresh              JMI         Horror
# 44              JMI_Doc5_Fresh              JMI         Horror
# 43              JMI_Doc4_Fresh              JMI         Horror
# 42              JMI_Doc3_Fresh              JMI         Horror
# 49             JMI_Doc10_Fresh              JMI         Horror
# 19                HLU_Doc10_US              HLU         Horror
# 29      DKX_Doc10_ItChapterTwo              DKX         Horror
# 99      KKN_Doc10_ToxicAvenger       KerryKurcz         Horror
# 27       DKX_Doc8_ItChapterTwo              DKX         Horror
# 26       DKX_Doc7_ItChapterTwo              DKX         Horror
# 25       DKX_Doc6_ItChapterTwo              DKX         Horror
# 28       DKX_Doc9_ItChapterTwo              DKX         Horror
# 23       DKX_Doc4_ItChapterTwo              DKX         Horror
# 22       DKX_Doc3_ItChapterTwo              DKX         Horror
# 21       DKX_Doc2_ItChapterTwo              DKX         Horror
# 24       DKX_Doc5_ItChapterTwo              DKX         Horror
# 179       JSA_Doc10_PitchBlack    Jeremy Savill         Sci-Fi
# 172        JSA_Doc3_PitchBlack    Jeremy Savill         Sci-Fi
# 173        JSA_Doc4_PitchBlack    Jeremy Savill         Sci-Fi
# 174        JSA_Doc5_PitchBlack    Jeremy Savill         Sci-Fi
# 175        JSA_Doc6_PitchBlack    Jeremy Savill         Sci-Fi
# 176        JSA_Doc7_PitchBlack    Jeremy Savill         Sci-Fi
# 177        JSA_Doc8_PitchBlack    Jeremy Savill         Sci-Fi
# 178        JSA_Doc9_PitchBlack    Jeremy Savill         Sci-Fi
# 30        DRN_Doc1_EQUILIBRIUM              DRN         Sci-Fi
# 34        DRN_Doc5_EQUILIBRIUM              DRN         Sci-Fi
# 32        DRN_Doc3_EQUILIBRIUM              DRN         Sci-Fi
# 33        DRN_Doc4_EQUILIBRIUM              DRN         Sci-Fi
# 171        JSA_Doc2_PitchBlack    Jeremy Savill         Sci-Fi
# 35        DRN_Doc6_EQUILIBRIUM              DRN         Sci-Fi
# 36        DRN_Doc7_EQUILIBRIUM              DRN         Sci-Fi
# 37        DRN_Doc8_EQUILIBRIUM              DRN         Sci-Fi
# 38        DRN_Doc9_EQUILIBRIUM              DRN         Sci-Fi
# 39       DRN_Doc10_EQUILIBRIUM              DRN         Sci-Fi
# 31        DRN_Doc2_EQUILIBRIUM              DRN         Sci-Fi
# 109   RSV_Doc10_MinorityReport              RSV         Sci-Fi
# 108    RSV_Doc9_MinorityReport              RSV         Sci-Fi
# 131          JTG_Doc2_Oblivion              JTG         Sci-Fi
# 107    RSV_Doc8_MinorityReport              RSV         Sci-Fi
# 106    RSV_Doc7_MinorityReport              RSV         Sci-Fi
# 105    RSV_Doc6_MinorityReport              RSV         Sci-Fi
# 104    RSV_Doc5_MinorityReport              RSV         Sci-Fi
# 103    RSV_Doc4_MinorityReport              RSV         Sci-Fi
# 102    RSV_Doc3_MinorityReport              RSV         Sci-Fi
# 101    RSV_Doc2_MinorityReport              RSV         Sci-Fi
# 100    RSV_Doc1_MinorityReport              RSV         Sci-Fi
# 150            JLV_Doc1_Batman              JLV         Sci-Fi
# 151            JLV_Doc2_Batman              JLV         Sci-Fi
# 152            JLV_Doc3_Batman              JLV         Sci-Fi
# 153            JLV_Doc4_Batman              JLV         Sci-Fi
# 130          JTG_Doc1_Oblivion              JTG         Sci-Fi
# 154            JLV_Doc5_Batman              JLV         Sci-Fi
# 156            JLV_Doc7_Batman              JLV         Sci-Fi
# 157            JLV_Doc8_Batman              JLV         Sci-Fi
# 158            JLV_Doc9_Batman              JLV         Sci-Fi
# 159           JLV_Doc10_Batman              JLV         Sci-Fi
# 139         JTG_Doc10_Oblivion              JTG         Sci-Fi
# 138          JTG_Doc9_Oblivion              JTG         Sci-Fi
# 137          JTG_Doc8_Oblivion              JTG         Sci-Fi
# 136          JTG_Doc7_Oblivion              JTG         Sci-Fi
# 135          JTG_Doc6_Oblivion              JTG         Sci-Fi
# 134          JTG_Doc5_Oblivion              JTG         Sci-Fi
# 133          JTG_Doc4_Oblivion              JTG         Sci-Fi
# 132          JTG_Doc3_Oblivion              JTG         Sci-Fi
# 155            JLV_Doc6_Batman              JLV         Sci-Fi
# 170        JSA_Doc1_PitchBlack    Jeremy Savill         Sci-Fi
#
#     Review Type (pos or neg)        Movie Title  \
# 0                   Negative               Taxi
# 116                 Positive   Angel Has Fallen
# 115                 Positive   Angel Has Fallen
# 114                 Negative   Angel Has Fallen
# 113                 Negative   Angel Has Fallen
# 112                 Negative   Angel Has Fallen
# 111                 Negative   Angel Has Fallen
# 110                 Negative   Angel Has Fallen
# 117                 Positive   Angel Has Fallen
# 198                 Negative          Inception
# 78                  Negative     No Time To Die
# 77                  Negative     No Time To Die
# 76                  Negative     No Time To Die
# 75                  Negative     No Time To Die
# 74                  Positive     No Time To Die
# 73                  Positive     No Time To Die
# 72                  Positive     No Time To Die
# 79                  Negative     No Time To Die
# 118                 Positive   Angel Has Fallen
# 119                 Positive   Angel Has Fallen
# 180                 Positive              Taken
# 197                 Negative          Inception
# 196                 Negative          Inception
# 195                 Negative          Inception
# 194                 Positive          Inception
# 193                 Positive          Inception
# 192                 Positive          Inception
# 191                 Positive          Inception
# 190                 Positive          Inception
# 189                 Negative              Taken
# 188                 Negative              Taken
# 187                 Negative              Taken
# 186                 Negative              Taken
# 185                 Negative              Taken
# 184                 Positive              Taken
# 183                 Positive              Taken
# 182                 Positive              Taken
# 181                 Positive              Taken
# 71                  Positive     No Time To Die
# 70                  Positive     No Time To Die
# 199                 Negative          Inception
# 1                   Positive               Taxi
# 2                   Negative               Taxi
# 3                   Negative               Taxi
# 4                   Negative               Taxi
# 5                   Negative               Taxi
# 6                   Positive               Taxi
# 7                   Positive               Taxi
# 8                   Positive               Taxi
# 9                   Positive               Taxi
# 120                 Positive    Despicable Me 3
# 148                 Positive      The Lost City
# 149                 Positive      The Lost City
# 89                  Positive     Legally Blonde
# 88                  Positive     Legally Blonde
# 83                  Negative     Legally Blonde
# 86                  Positive     Legally Blonde
# 85                  Positive     Legally Blonde
# 84                  Negative     Legally Blonde
# 147                 Positive      The Lost City
# 82                  Negative     Legally Blonde
# 87                  Positive     Legally Blonde
# 146                 Positive      The Lost City
# 141                 Negative      The Lost City
# 144                 Negative      The Lost City
# 143                 Negative      The Lost City
# 142                 Negative      The Lost City
# 81                  Negative     Legally Blonde
# 140                 Negative      The Lost City
# 129                 Negative    Despicable Me 3
# 128                 Negative    Despicable Me 3
# 127                 Negative    Despicable Me 3
# 126                 Negative    Despicable Me 3
# 125                 Negative    Despicable Me 3
# 124                 Positive    Despicable Me 3
# 123                 Positive    Despicable Me 3
# 122                 Positive    Despicable Me 3
# 145                 Positive      The Lost City
# 121                 Positive    Despicable Me 3
# 80                  Negative     Legally Blonde
# 57                  Positive  Holmes and Watson
# 65                  Negative      Dirty Grandpa
# 64                  Positive      Dirty Grandpa
# 63                  Positive      Dirty Grandpa
# 62                  Positive      Dirty Grandpa
# 61                  Positive      Dirty Grandpa
# 60                  Positive      Dirty Grandpa
# 59                  Positive  Holmes and Watson
# 58                  Positive  Holmes and Watson
# 66                  Negative      Dirty Grandpa
# 67                  Negative      Dirty Grandpa
# 69                  Negative      Dirty Grandpa
# 56                  Positive  Holmes and Watson
# 55                  Positive  Holmes and Watson
# 54                  Negative  Holmes and Watson
# 53                  Negative  Holmes and Watson
# 52                  Negative  Holmes and Watson
# 51                  Negative  Holmes and Watson
# 50                  Negative  Holmes and Watson
# 68                  Negative      Dirty Grandpa
# 17                  Negative                 US
# 160                 Positive    Drag me to hell
# 161                 Positive    Drag me to hell
# 16                  Negative                 US
# 15                  Negative                 US
# 14                  Positive                 US
# 13                  Positive                 US
# 12                  Positive                 US
# 11                  Positive                 US
# 10                  Positive                 US
# 169                 Negative    Drag me to hell
# 168                 Negative    Drag me to hell
# 167                 Negative    Drag me to hell
# 166                 Negative    Drag me to hell
# 165                 Negative    Drag me to hell
# 164                 Positive    Drag me to hell
# 163                 Positive    Drag me to hell
# 162                 Positive    Drag me to hell
# 18                  Negative                 US
# 40                  Negative              Fresh
# 41                  Negative              Fresh
# 20                  Positive     It Chapter Two
# 97                  Negative  The Toxic Avenger
# 96                  Negative  The Toxic Avenger
# 95                  Negative  The Toxic Avenger
# 94                  Positive  The Toxic Avenger
# 93                  Positive  The Toxic Avenger
# 92                  Positive  The Toxic Avenger
# 91                  Positive  The Toxic Avenger
# 98                  Negative  The Toxic Avenger
# 90                  Positive  The Toxic Avenger
# 48                  Positive              Fresh
# 47                  Positive              Fresh
# 46                  Positive              Fresh
# 45                  Positive              Fresh
# 44                  Negative              Fresh
# 43                  Negative              Fresh
# 42                  Negative              Fresh
# 49                  Positive              Fresh
# 19                  Negative                 US
# 29                  Negative     It Chapter Two
# 99                  Negative  The Toxic Avenger
# 27                  Negative     It Chapter Two
# 26                  Negative     It Chapter Two
# 25                  Negative     It Chapter Two
# 28                  Negative     It Chapter Two
# 23                  Positive     It Chapter Two
# 22                  Positive     It Chapter Two
# 21                  Positive     It Chapter Two
# 24                  Positive     It Chapter Two
# 179                 Positive        Pitch Black
# 172                 Negative        Pitch Black
# 173                 Positive        Pitch Black
# 174                 Positive        Pitch Black
# 175                 Positive        Pitch Black
# 176                 Negative        Pitch Black
# 177                 Negative        Pitch Black
# 178                 Negative        Pitch Black
# 30                  Negative        Equilibrium
# 34                  Negative        Equilibrium
# 32                  Negative        Equilibrium
# 33                  Negative        Equilibrium
# 171                 Negative        Pitch Black
# 35                  Positive        Equilibrium
# 36                  Positive        Equilibrium
# 37                  Positive        Equilibrium
# 38                  Positive        Equilibrium
# 39                  Positive        Equilibrium
# 31                  Negative        Equilibrium
# 109                 Negative    Minority Report
# 108                 Negative    Minority Report
# 131                 Negative           Oblivion
# 107                 Negative    Minority Report
# 106                 Negative    Minority Report
# 105                 Negative    Minority Report
# 104                 Positive    Minority Report
# 103                 Positive    Minority Report
# 102                 Positive    Minority Report
# 101                 Positive    Minority Report
# 100                 Positive    Minority Report
# 150                 Positive             Batman
# 151                 Positive             Batman
# 152                 Positive             Batman
# 153                 Positive             Batman
# 130                 Negative           Oblivion
# 154                 Positive             Batman
# 156                 Negative             Batman
# 157                 Negative             Batman
# 158                 Negative             Batman
# 159                 Negative             Batman
# 139                 Positive           Oblivion
# 138                 Positive           Oblivion
# 137                 Positive           Oblivion
# 136                 Positive           Oblivion
# 135                 Positive           Oblivion
# 134                 Negative           Oblivion
# 133                 Negative           Oblivion
# 132                 Negative           Oblivion
# 155                 Negative             Batman
# 170                 Positive        Pitch Black
#
#                                                 Tokens  \
# 0    [Jimmy, Fallon, 's, big, screen, career, may, ...
# 116  [Authorities, take, Secret, Service, agent, Mi...
# 115  [American, movie, presidents, can, only, make,...
# 114  [No, ,, you, dont, need, to, have, seen, Oly...
# 113  [There, is, a, certain, mindless, pleasure, in...
# 112  [Ric, Roman, Waughs, Angel, Has, Fallen, sees...
# 111  [Who, ARE, all, these, people, ?, , That, wa...
# 110  [Boredom, sets, in, long, before, the, start, ...
# 117  [Angel, Has, Fallen, is, what, used, to, be, c...
# 198  [After, reading, all, the, amazing, reviews, a...
# 78   [The, new, James, Bond, movie, “, No, Time, To...
# 77   [For, those, whose, cinematic, consciousness, ...
# 76   [Let, the, mourning, begin, ., In, No, Time, t...
# 75   [No, Time, to, Die, ,, the, latest, and, last,...
# 74   [James, Bond, (, Daniel, Craig, ,, in, reporte...
# 73   [No, Time, to, Die, is, an, outstanding, end, ...
# 72   [James, Bond, has, saved, the, world, two, doz...
# 79   [Daniel, Craig, makes, his, royal, exit, in, `...
# 118  [Any, spy, thriller, character, who, hangs, ar...
# 119  [Butler, delivers, a, good, performance, as, B...
# 180  [Liam, Neeson, flashes, a, telltale, Harrison,...
# 197  [Unless, you, call, this, movie, a, masterpiec...
# 196  [You, have, this, basic, idea, and, the, story...
# 195  [Inception, makes, the, average, moviegoer, fe...
# 194  [Inception, is, a, movie, that, works, outside...
# 193  [Inception, has, a, problem, that, I, can, not...
# 192  [Only, a, small, handful, of, directors, have,...
# 191  [Surrealism, can, appear, to, be, ineffably, b...
# 190  [I, 'm, nearly, at, a, loss, for, words, ., Ju...
# 189  [Liam, Neeson, was, up, forbut, never, got, t...
# 188  [Any, parent, could, relate, to, Bryan, Mills,...
# 187  [If, there, are, any, 24, fans, who, have, won...
# 186  [You, can, see, that, in, the, way, the, film,...
# 185  [Taken, is, the, latest, film, from, the, Fren...
# 184  [Taken, :, Action, thriller, ., Starring, Liam...
# 183  [Takens, greatest, asset, resides, within, t...
# 182  [Who, knew, Liam, Neeson, ,, the, same, highly...
# 181  [Maybe, I, was, just, in, a, really, good, moo...
# 71   [If, there, ’, s, one, consistency, in, the, D...
# 70   [Now, he, ’, s, come, to, the, end, of, his, r...
# 199  [A, shame, that, this, movie, is, rated, so, h...
# 1    [After, getting, nominated, for, ``, Chicago, ...
# 2    [Queen, Latifah, handily, walked, away, with, ...
# 3    [So, Jimmy, Fallon, leaves, ÒSaturday, Night, ...
# 4    [TaxiÊcasts, JimmyÊFallon, as, Officer, Andy, ...
# 5    [Jimmy, Fallon, needs, to, call, Tina, Fey, an...
# 6    [How, one, likes, ``, Taxi, '', has, everythin...
# 7    [ChicagoÕs, Queen, Latifah, andÊSaturday, Nigh...
# 8    [After, five, years, of, waiting, ,, Belle, Wi...
# 9    [On, her, first, day, as, a, taxi, driver, ,, ...
# 120  [As, former, super-villain, Gru, (, Steve, Car...
# 148  [There, was, a, certain, flavor, of, film, tha...
# 149  [The, Lost, City, is, exactly, what, it, says,...
# 89   [Do, n't, judge, a, book, by, it, 's, cover, ....
# 88   [I, did, n't, go, into, ``, Legally, Blonde, '...
# 83   [Reese, Witherspoon, is, just, 25, years, old,...
# 86   [Written, by, Kirsten, Smith, and, Karen, McCu...
# 85   [If, her, dazzling, turns, inÊElection, ,, Fre...
# 84   [Legally, Blonde, ,, a, hefty, handful, of, fu...
# 147  [There, are, few, things, as, uplifting, as, t...
# 82   [Say, all, you, will, about, the, animated, Dr...
# 87   [It, 's, not, that, easy, to, simultaneously, ...
# 146  [Channing, Tatum, plays, himbos, like, Mozart,...
# 141  [In, a, setup, and, general, vibe, that, remin...
# 144  [Once, again, ,, a, comedy, that, relies, on, ...
# 143  [Sandra, Bullock, recently, announced, that, s...
# 142  [Loretta, Sage, has, an, interesting, past, .,...
# 81   [Legally, BlondeÊis, ,, of, course, ,, a, pun,...
# 140  [Aaron, and, Adam, Nees, The, Lost, City, is,...
# 129  [Let, 's, face, it, Illumination, Entertainmen...
# 128  [Once, upon, a, time, Gru, (, Steve, Carrell, ...
# 127  [Unlike, most, films, in, Illuminations, cano...
# 126  [I, never, thought, Id, complain, about, a, D...
# 125  [At, what, point, to, film, series, and, franc...
# ...
# 97   [force, give, movie, anything, lower, 5/10, ,,...
# 96   [toxic, avenger, start, shot, new, york, city,...
# 95   [say, positive, thing, toxic, avenger, knew, w...
# 94   [toxic, avenger, excellent, hilarious, horror,...
# 93   [toxic, avenger, 21st, anniversary, ed, ., 2, ...
# 92   ['ve, never, seen, troma, film, remember, watc...
# 91   [wa, teenager, ,, available, place, watch, tra...
# 98   [four, crazed, teenager, speed, road, car, ,, ...
# 90   [film, believe, one, favorate, film, time, ,, ...
# 48   [opening, credit, fresh, n't, arrive, 33-minut...
# 47   [saw, netflix, 's, recent, ``, tinder, swindle...
# 46   [mimi, caves, debut, feature, fresh, sits, tr...
# 45   [every, ,, movie, come, along, challenge, talk...
# 44   [modern, dating, make, girl, feel, like, real,...
# 43   [line, horror, ,, storytelling, go, tense, tra...
# 42   [modern, dating, banal, dehumanizing, ., commo...
# 49   [matter, many, digital, barricade, place, u, ...
# 19   [would, love, able, say, jordan, peele, ’, u, ...
# 29   [2017, stephen, king, adaptation, took, seriou...
# 99   [world, movie, ,, many, know, main, genre, cov...
# 27   [seven, far-flung, member, so-called, losers,...
# 26   [nearly, 90, year, ago, fritz, langs, ,, sing...
# 25   [point, scary, thing, lose, power, ?, 's, ques...
# 28   [its, wretched, ,, ugly, ,, unseemly, serf, r...
# 23   [isnt, pennywise, clown, terrifying, it, cha...
# 22   [guess, whos, back, ,, back, chapter, one, wa...
# 21   [chapter, one, ,, whatever, must, call, since,...
# 24   [its, twenty-seven, year, since, losers, clu...
# 179  [sometimes, ,, take, movie, face, value, ., ca...
# 172  ['s, sci-fi, season, ,, opening, volley, twohy...
# 173  [packed, razzle-dazzle, special, effect, fuele...
# 174  [richard, b., riddick, (, vin, diesel, ), can...
# 175  ['s, ?, passenger, spaceship, hit, rogue, aste...
# 176  [good, alien, anymore, ., title, character, 19...
# 177  [active, contempt, audience, ,, wonder, ,, pro...
# 178  [spaceship, crash-lands, planet, three, sun, p...
# 30   [tedious, rip-off, sci-fi, film, ,, itching, a...
# 34   [tried, watching, equilibrium, year, ago, ,, c...
# 32   [equilibrium, movie, search, plot, ., writer/d...
# 33   [three, movie, buff, patrick, -, negative, equ...
# 171  [movie, opening, thrill, vast, ship, interstel...
# 35   [happens, matrix, fahrenheit, 451, get, drunk,...
# 36   [tread, dream, ., benjamin, franklin, said, ,,...
# 37   [bale, bale, future, one, hand, ``, equilibriu...
# 38   [constantly, racing, mind, robert, barbere, fi...
# 39   [roger, ebert, christian, bale, '', equilibriu...
# 31   [equilibrium, doe, n't, much, invoke, feeling,...
# 109  [new, hell, ?, shallow, ,, noisy, pretentious,...
# 108  [minority, report, ,, futuristic, thriller, se...
# 131  [``, oblivion, '', big, sci-fi, movie, take, i...
# 107  [set, year, 2054, ,, steven, spielberg, 's, mi...
# 106  [year, graced, futuristic, sci-fi, flick, base...
# 105  [minority, report, ,, directed, steven, spielb...
# 104  [steven, spielberg, 's, minority, report, busy...
# 103  [“, minority, report, ”, un-spielberg, film, e...
# 102  [year, 2054, ,, department, precrime, washingt...
# 101  [movie, ’, future, (, 2054, ), see, washington...
# 100  [steven, spielberg, ’, minority, report, reali...
# 150  [warner, brother, announced, going, make, ``, ...
# 151  [iõve, watched, movie, batman, point, almost, ...
# 152  [created, 50, year, ago, comic, book, hero, ,,...
# 153  [occasionally, laughable, mostly, tinged, morb...
# 130  [recently, ,, tom, cruise, looked, wa, attempt...
# 154  [theatrical, release, batman, celebrates, 30, ...
# 156  [critic, adored, batman, eccentric, ,, burtone...
# 157  [``, bad, film, capable, director, ., '', one,...
# 158  [despite, representing, newfound, status, majo...
# 159  [tim, burtonõs, generally, well-regarded, 1989...
# 139  [oblivion, competently, made, sci-fi, action...
# 138  [film, genre, boom, year, bust, year, ., every...
# 137  [sort, eternal, return, played, ruin, post-apo...
# 136  [although, universals, publicity, department,...
# 135  [oblivion, look, marvelous, ,, deliciously, ...
# 134  [need, ultimate, tom, cruise, vehicle, ?, vehi...
# 133  [oblivion, ,, , tom, cruise, play, post-apoc...
# 132  [co-writer-director, joseph, kosinski, (, tro...
# 155  [trailer, ha, already, hinted, ,, òbatmanó, (,...
# 170  ['s, vin, diesel, week, !, suddenly, ,, largel...
#
#                                          wrangle_three
# 0    [jimmy, fallon, s, big, screen, career, may, e...
# 116  [authority, take, secret, service, agent, mike...
# 115  [american, movie, president, make, u, wistful,...
# 114  [dont, need, seen, olympus, ha, fallen, andor,...
# 113  [certain, mindless, pleasure, fallen, movie, w...
# 112  [ric, roman, waughs, angel, ha, fallen, see, u...
# 111  [who, people, wa, muttered, entered, first, sc...
# 110  [boredom, set, long, start, angel, ha, fallen,...
# 117  [angel, ha, fallen, used, called, b, movie, de...
# 198  [reading, amazing, review, seeing, score, rd, ...
# 78   [new, james, bond, movie, time, die, th, offic...
# 77   [whose, cinematic, consciousness, predates, st...
# 76   [let, mourning, begin, time, die, james, bond,...
# 75   [time, die, latest, last, appearance, daniel, ...
# 74   [james, bond, daniel, craig, reportedly, last,...
# 73   [time, die, outstanding, end, daniel, craig, j...
# 72   [james, bond, ha, saved, world, two, dozen, ti...
# 79   [daniel, craig, make, royal, exit, time, die, ...
# 118  [spy, thriller, character, hang, around, long,...
# 119  [butler, delivers, good, performance, banning,...
# 180  [liam, neeson, flash, telltale, harrison, ford...
# 197  [unless, call, movie, masterpiece, damn, word,...
# 196  [basic, idea, story, good, boy, money, cgi, sp...
# 195  [inception, make, average, moviegoer, feel, sm...
# 194  [inception, movie, work, outside, logic, feel,...
# 193  [inception, ha, problem, bear, constant, someo...
# 192  [small, handful, director, ability, make, audi...
# 191  [surrealism, appear, ineffably, bizarre, inqui...
# 190  [m, nearly, loss, word, thought, christopher, ...
# 189  [liam, neeson, wa, forbut, never, got, playjam...
# 188  [parent, could, relate, bryan, mill, liam, nee...
# 187  [fan, wondered, tv, series, might, like, liam,...
# 186  [see, way, film, portrays, neeson, s, characte...
# 185  [taken, latest, film, french, filmmaker, luc, ...
# 184  [taken, action, thriller, starring, liam, nees...
# 183  [takens, greatest, asset, resides, within, per...
# 182  [knew, liam, neeson, highly, regarded, actor, ...
# 181  [maybe, wa, really, good, mood, saw, found, ta...
# 71   [one, consistency, daniel, craig, james, bond,...
# 70   [come, end, run, daniel, craig, james, bond, r...
# 199  [shame, movie, rated, highly, imdb, let, tell,...
# 1    [getting, nominated, chicago, making, boxoffic...
# 2    [queen, latifah, handily, walked, away, show, ...
# 3    [jimmy, fallon, leaf, saturday, night, live, i...
# 4    [taxicasts, jimmyfallon, officer, andy, washbu...
# 5    [jimmy, fallon, need, call, tina, fey, beg, wr...
# 6    [one, like, taxi, ha, everything, one, respond...
# 7    [chicagos, queen, latifah, andsaturday, night,...
# 8    [five, year, waiting, belle, williams, queen, ...
# 9    [first, day, taxi, driver, wild, belle, find, ...
# 120  [former, supervillain, gru, steve, carell, try...
# 148  [wa, certain, flavor, film, used, see, fairly,...
# 149  [lost, city, exactly, say, tin, appreciate, ho...
# 89   [nt, judge, book, s, cover, old, saying, ve, h...
# 88   [nt, go, legally, blonde, expecting, much, rar...
# 83   [reese, witherspoon, year, old, s, making, maj...
# 86   [written, kirsten, smith, karen, mccullah, lut...
# 85   [dazzling, turn, inelection, freeway, andthe, ...
# 84   [legally, blonde, hefty, handful, funny, joke,...
# 147  [thing, uplifting, embrace, laughter, one, lov...
# 82   [say, animated, dr, aki, ross, infinal, fantas...
# 87   [s, easy, simultaneously, make, fun, something...
# 146  [channing, tatum, play, himbos, like, mozart, ...
# 141  [setup, general, vibe, reminded, film, like, r...
# 144  [comedy, relies, gimmick, premise, charm, lead...
# 143  [sandra, bullock, recently, announced, shed, t...
# 142  [loretta, sage, ha, interesting, past, studied...
# 81   [legally, blondeis, course, pun, legally, blin...
# 140  [aaron, adam, nees, lost, city, one, rare, mov...
# 129  [let, s, face, illumination, entertainment, un...
# 128  [upon, time, gru, steve, carrell, wa, chromedo...
# 127  [unlike, film, illuminations, canon, despicabl...
# 126  [never, thought, id, complain, despicable, mov...
# 125  [point, film, series, franchise, begin, lose, ...
# 124  [im, confident, minion, would, gleefully, foll...
# 123  [although, reader, imdbcom, critic, rotten, to...
# 122  [lets, start, saying, kid, wore, matching, min...
# 145  [taken, hostage, romanceadventure, novelist, c...
# 121  [animation, feature, answer, one, question, ma...
# 80   [newcomer, robert, luketic, make, feature, fil...
# 57   [etan, cohen, didnt, write, holmes, watson, ve...
# 65   [make, mistake, robert, de, niro, bona, fide, ...
# 64   [hope, high, dirty, grandpa, simply, mere, exi...
# 63   [okay, know, may, thinking, dirty, grandpa, ne...
# 62   [s, dirty, grandpa, wa, certainly, divisive, m...
# 61   [re, probably, going, read, whole, thing, titl...
# 60   [dirty, grandpa, ha, approval, rating, rotten,...
# 59   [maybe, its, holiday, spirit, cant, find, part...
# 58   [finding, went, wrong, holmes, watson, ferrell...
# 66   [disturbing, difficult, movie, watch, someday,...
# 67   [jan, dirty, grandpa, wa, unleashed, unsuspect...
# 69   [robert, de, niro, receives, inevitable, lifet...
# 56   [one, years, critically, shellacked, movie, pr...
# 55   [many, distinguished, actor, played, sherlock,...
# 54   [start, holmes, watson, cynical, inexplicable,...
# 53   [previously, undiscovered, short, story, show,...
# 52   [s, moment, stunningly, abysmal, holmes, watso...
# 51   [morbid, curiosity, perhaps, selfdestructive, ...
# 50   [remember, scene, step, brother, sleepwalking,...
# 68   [humor, must, acknowledged, entirely, subjecti...
# 17   [directorial, debut, shattering, jordan, peele...
# 160  [drag, hell, heroine, christine, brown, alison...
# 161  [properly, fairly, access, experience, seeing,...
# 16   [doppelgnger, going, kill, shower, jordan, pee...
# 15   [say, lightning, strike, twice, sometimes, doe...
# 14   [jordan, peele, thriller, get, turned, one, ha...
# 13   [probably, agree, looking, phone, talking, mov...
# 12   [idyllic, vacation, turn, living, nightmare, f...
# 11   [lupita, nyong, star, jordan, peele, newest, h...
# 10   [uninterested, deep, dive, sophomore, film, bu...
# 169  [wa, elementary, school, classmate, named, don...
# 168  [title, drag, hell, offer, literal, ironic, in...
# 167  [oh, another, pg, horror, film, wait, say, s, ...
# 166  [drag, hell, find, sam, raimi, returning, schl...
# 165  [way, theater, tell, buddy, ha, imdb, must, go...
# 164  [intense, opening, scene, stellar, shocking, f...
# 163  [drag, hell, wa, one, ultimate, moviegoing, ex...
# 162  [two, great, movie, opening, weekend, crotchet...
# 18   [writerdirector, jordan, peele, get, wa, brash...
# 40   [sebastian, stan, dullest, actor, working, tod...
# 41   [central, idea, fresh, either, blunt, metaphor...
# 20   [stephen, king, took, page, tell, story, it, h...
# 97   [force, give, movie, anything, lower, though, ...
# 96   [toxic, avenger, start, shot, new, york, city,...
# 95   [say, positive, thing, toxic, avenger, knew, w...
# 94   [toxic, avenger, excellent, hilarious, horror,...
# 93   [toxic, avenger, st, anniversary, ed, disc, se...
# 92   [ve, never, seen, troma, film, remember, watch...
# 91   [wa, teenager, available, place, watch, trash,...
# 98   [four, crazed, teenager, speed, road, car, wil...
# 90   [film, believe, one, favorate, film, time, s, ...
# 48   [opening, credit, fresh, nt, arrive, minute, m...
# 47   [saw, netflix, s, recent, tinder, swindler, th...
# 46   [mimi, caves, debut, feature, fresh, sits, tri...
# 45   [every, movie, come, along, challenge, talk, d...
# 44   [modern, dating, make, girl, feel, like, real,...
# 43   [line, horror, storytelling, go, tense, trauma...
# 42   [modern, dating, banal, dehumanizing, common, ...
# 49   [matter, many, digital, barricade, place, u, s...
# 19   [would, love, able, say, jordan, peele, u, wor...
# 29   [stephen, king, adaptation, took, serious, tur...
# 99   [world, movie, many, know, main, genre, cover,...
# 27   [seven, farflung, member, socalled, losers, cl...
# 26   [nearly, year, ago, fritz, langs, single, ball...
# 25   [point, scary, thing, lose, power, s, question...
# 28   [its, wretched, ugly, unseemly, serf, real, pu...
# 23   [isnt, pennywise, clown, terrifying, it, chapt...
# 22   [guess, whos, back, back, chapter, one, wa, bo...
# 21   [chapter, one, whatever, must, call, since, ma...
# 24   [its, twentyseven, year, since, losers, club, ...
# 179  [sometimes, take, movie, face, value, ca, nt, ...
# 172  [s, scifi, season, opening, volley, twohy, arr...
# 173  [packed, razzledazzle, special, effect, fueled...
# 174  [richard, b, riddick, vin, diesel, cant, seem,...
# 175  [s, passenger, spaceship, hit, rogue, asteroid...
# 176  [good, alien, anymore, title, character, s, al...
# 177  [active, contempt, audience, wonder, propels, ...
# 178  [spaceship, crashlands, planet, three, sun, pl...
# 30   [tedious, ripoff, scifi, film, itching, anothe...
# 34   [tried, watching, equilibrium, year, ago, coul...
# 32   [equilibrium, movie, search, plot, writerdirec...
# 33   [three, movie, buff, patrick, negative, equili...
# 171  [movie, opening, thrill, vast, ship, interstel...
# 35   [happens, matrix, fahrenheit, get, drunk, care...
# 36   [tread, dream, benjamin, franklin, said, sacri...
# 37   [bale, bale, future, one, hand, equilibrium, b...
# 38   [constantly, racing, mind, robert, barbere, fi...
# 39   [roger, ebert, christian, bale, equilibrium, w...
# 31   [equilibrium, doe, nt, much, invoke, feeling, ...
# 109  [new, hell, shallow, noisy, pretentious, minor...
# 108  [minority, report, futuristic, thriller, set, ...
# 131  [oblivion, big, scifi, movie, take, idea, spac...
# 107  [set, year, steven, spielberg, s, minority, re...
# 106  [year, graced, futuristic, scifi, flick, based...
# 105  [minority, report, directed, steven, spielberg...
# 104  [steven, spielberg, s, minority, report, busy,...
# 103  [minority, report, unspielberg, film, ever, ma...
# 102  [year, department, precrime, washington, dc, c...
# 101  [movie, future, see, washington, dc, system, k...
# 100  [steven, spielberg, minority, report, realizes...
# 150  [warner, brother, announced, going, make, batm...
# 151  [ive, watched, movie, batman, point, almost, r...
# 152  [created, year, ago, comic, book, hero, charac...
# 153  [occasionally, laughable, mostly, tinged, morb...
# 130  [recently, tom, cruise, looked, wa, attempting...
# 154  [theatrical, release, batman, celebrates, year...
# 156  [critic, adored, batman, eccentric, burtonesqu...
# 157  [bad, film, capable, director, one, pioneering...
# 158  [despite, representing, newfound, status, majo...
# 159  [tim, burtons, generally, wellregarded, batman...
# 139  [oblivion, competently, made, scifi, action, m...
# 138  [film, genre, boom, year, bust, year, every, g...
# 137  [sort, eternal, return, played, ruin, postapoc...
# 136  [although, universals, publicity, department, ...
# 135  [oblivion, look, marvelous, deliciously, dysto...
# 134  [need, ultimate, tom, cruise, vehicle, vehicle...
# 133  [oblivion, tom, cruise, play, postapocalyptic,...
# 132  [cowriterdirector, joseph, kosinski, tron, leg...
# 155  [trailer, ha, already, hinted, batman, citywid...
# 170  [s, vin, diesel, week, suddenly, largely, unkn...

# %% [markdown]
# #### Text Vectorization using tf-idf

# %%
def get_top_n_words(tfidf_vector, feature_names, n=10):
    # Calculate mean tfidf frequency of each term through documents
    means = tfidf_vector.mean(axis=0)

    # Connecting term to its mean frequency
    data = []
    for col, term in enumerate(feature_names):
        data.append((term, means[0, col]))

    ranking = pd.DataFrame(data, columns=['term', 'mean_tfidf'])
    ranking = ranking.sort_values('mean_tfidf', ascending=False)
    
    return pd.DataFrame(ranking.head(n)).reset_index(drop=True).round(4)

# %%
corpus_one = []
for document in wrangled_data.loc[:,'wrangle_one']:
    for token in document:
        corpus_one.append(token)

corpus_two = []
for document in wrangled_data.loc[:,'wrangle_two']:
    for token in document:
        corpus_two.append(token)

corpus_three = []
for document in wrangled_data.loc[:,'wrangle_three']:
    for token in document:
        corpus_three.append(token)

tfidf_vectorizer_one = TfidfVectorizer()
tfidf_vectorizer_two = TfidfVectorizer()
tfidf_vectorizer_three = TfidfVectorizer()

tfidf_one = tfidf_vectorizer_one.fit_transform(corpus_one)
tfidf_two = tfidf_vectorizer_two.fit_transform(corpus_two)
tfidf_three = tfidf_vectorizer_three.fit_transform(corpus_three)

feature_names_one = tfidf_vectorizer_one.get_feature_names_out()
feature_names_two = tfidf_vectorizer_two.get_feature_names_out()
feature_names_three = tfidf_vectorizer_three.get_feature_names_out()

top_words_one = get_top_n_words(tfidf_one, feature_names_one, 50)
top_words_two = get_top_n_words(tfidf_two, feature_names_two, 50)
top_words_three = get_top_n_words(tfidf_three, feature_names_three, 50)

result = pd.concat([top_words_one, top_words_two, top_words_three], axis=1, keys=['Wrangle One', 'Wrangle Two', 'Wrangle Three'])
pd.DataFrame(result)
# Out:
#    Wrangle One            Wrangle Two            Wrangle Three
#           term mean_tfidf        term mean_tfidf          term mean_tfidf
# 0          the     0.0483        film     0.0085          film     0.0103
# 1          and     0.0241       movie     0.0069         movie     0.0085
# 2           of     0.0233          ha     0.0057            ha     0.0071
# 3           to     0.0225         one     0.0052           one     0.0063
# 4           in     0.0148          wa     0.0048            wa     0.0060
# 5           is     0.0143        like     0.0042          like     0.0051
# 6         that     0.0114        time     0.0036          time     0.0045
# 7           it     0.0111         get     0.0031           get     0.0038
# 8           as     0.0078        make     0.0030          make     0.0037
# 9         with     0.0078   character     0.0028            nt     0.0035
# 10         for     0.0067        even     0.0027     character     0.0034
# 11         but     0.0061       scene     0.0025          even     0.0033
# 12         his     0.0061         doe     0.0023         scene     0.0031
# 13          he     0.0054        much     0.0023           doe     0.0028
# 14        this     0.0052         way     0.0022          much     0.0028
# 15          on     0.0050       would     0.0022           way     0.0027
# 16        film     0.0045      action     0.0021         would     0.0027
# 17         are     0.0042        also     0.0020          also     0.0025
# 18          be     0.0041       thing     0.0020        action     0.0025
# 19          an     0.0040       first     0.0019         thing     0.0025
# 20          by     0.0038        come     0.0019          come     0.0024
# 21         you     0.0038        take     0.0019           its     0.0024
# 22         not     0.0037       story     0.0018         first     0.0023
# 23         her     0.0035        good     0.0018          take     0.0023
# 24         has     0.0035         see     0.0017         story     0.0023
# 25          at     0.0034          go     0.0017          good     0.0022
# 26       movie     0.0033        well     0.0017           see     0.0022
# 27        from     0.0033        year     0.0017            go     0.0022
# 28         who     0.0033         two     0.0017          year     0.0021
# 29        have     0.0032        bond     0.0016           two     0.0021
# 30         one     0.0031        look     0.0016          well     0.0021
# 31         was     0.0030         new     0.0016          bond     0.0020
# 32         all     0.0029      people     0.0015          look     0.0020
# 33       there     0.0026        work     0.0015           new     0.0020
# 34         out     0.0025          it     0.0015        people     0.0019
# 35        like     0.0025       never     0.0015          work     0.0019
# 36        when     0.0024       world     0.0015         never     0.0018
# 37          or     0.0024        best     0.0014          best     0.0018
# 38          so     0.0024       could     0.0014         could     0.0017
# 39        more     0.0024      horror     0.0013         world     0.0017
# 40        they     0.0024      little     0.0013        little     0.0016
# 41          up     0.0024   something     0.0013     something     0.0016
# 42        what     0.0023        know     0.0013          know     0.0016
# 43         she     0.0022        feel     0.0013          feel     0.0016
# 44       their     0.0022        many     0.0013          many     0.0016
# 45       about     0.0021        back     0.0013        horror     0.0016
# 46       which     0.0020         set     0.0013          find     0.0016
# 47        into     0.0020        find     0.0012          back     0.0016
# 48         can     0.0020        life     0.0012           say     0.0016
# 49          if     0.0020         say     0.0012        though     0.0015

# %%
wrangled_data['tfidf_one'] = wrangled_data['wrangle_one'].apply(' '.join)
wrangled_data['tfidf_two'] = wrangled_data['wrangle_two'].apply(' '.join)
wrangled_data['tfidf_three'] = wrangled_data['wrangle_three'].apply(' '.join)

vectorizer_one = TfidfVectorizer()
vectorizer_two = TfidfVectorizer()
vectorizer_three = TfidfVectorizer()

tfidf_matrix_one = vectorizer_one.fit_transform(wrangled_data['tfidf_one'])
tfidf_matrix_two = vectorizer_two.fit_transform(wrangled_data['tfidf_two'])
tfidf_matrix_three = vectorizer_three.fit_transform(wrangled_data['tfidf_three'])

cosine_sim_one = cosine_similarity(tfidf_matrix_one)
cosine_sim_two = cosine_similarity(tfidf_matrix_two)
cosine_sim_three = cosine_similarity(tfidf_matrix_three)

fig, axs = plt.subplots(1,3,figsize=(20,6))

sns.heatmap(cosine_sim_one,ax=axs[0])
axs[0].set_title('Cosine Similarity Heatmap of Wrangle One')
sns.heatmap(cosine_sim_two,ax=axs[1])
axs[1].set_title('Wrangle Two')
sns.heatmap(cosine_sim_three,ax=axs[2])
axs[2].set_title('Wrangle Three')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Text Vectorization using Word2Vec

# %%
tokens = top_words_three.loc[0:100, 'term'].tolist()

corpus_one = [document for document in wrangled_data.loc[:, 'wrangle_one']]
corpus_two = [document for document in wrangled_data.loc[:, 'wrangle_two']]
corpus_three = [document for document in wrangled_data.loc[:, 'wrangle_three']]

model_one = Word2Vec(corpus_one, vector_size=100, window=5, min_count=1, workers=4)
model_two = Word2Vec(corpus_one, vector_size=200, window=5, min_count=1, workers=4)
model_three = Word2Vec(corpus_one, vector_size=300, window=5, min_count=1, workers=4)
model_four = Word2Vec(corpus_two, vector_size=100, window=5, min_count=1, workers=4)
model_five = Word2Vec(corpus_two, vector_size=200, window=5, min_count=1, workers=4)
model_six = Word2Vec(corpus_two, vector_size=300, window=5, min_count=1, workers=4)
model_seven = Word2Vec(corpus_three, vector_size=100, window=5, min_count=1, workers=4)
model_eight = Word2Vec(corpus_three, vector_size=200, window=5, min_count=1, workers=4)
model_nine = Word2Vec(corpus_three, vector_size=300, window=5, min_count=1, workers=4)

tokens_one = [token for token in tokens if token in model_one.wv.key_to_index]
tokens_two = [token for token in tokens if token in model_two.wv.key_to_index]
tokens_three = [token for token in tokens if token in model_three.wv.key_to_index]
tokens_four = [token for token in tokens if token in model_four.wv.key_to_index]
tokens_five = [token for token in tokens if token in model_five.wv.key_to_index]
tokens_six = [token for token in tokens if token in model_six.wv.key_to_index]
tokens_seven = [token for token in tokens if token in model_seven.wv.key_to_index]
tokens_eight = [token for token in tokens if token in model_eight.wv.key_to_index]
tokens_nine = [token for token in tokens if token in model_nine.wv.key_to_index]

vectors_one = np.array([model_one.wv[token] for token in tokens_one])
vectors_two = np.array([model_two.wv[token] for token in tokens_two])
vectors_three = np.array([model_three.wv[token] for token in tokens_three])
vectors_four = np.array([model_four.wv[token] for token in tokens_four])
vectors_five = np.array([model_five.wv[token] for token in tokens_five])
vectors_six = np.array([model_six.wv[token] for token in tokens_six])
vectors_seven = np.array([model_seven.wv[token] for token in tokens_seven])
vectors_eight = np.array([model_eight.wv[token] for token in tokens_eight])
vectors_nine = np.array([model_nine.wv[token] for token in tokens_nine])

vector_sets = [vectors_one, vectors_two, vectors_three, vectors_four, vectors_five, vectors_six, vectors_seven, vectors_eight, vectors_nine]
token_sets = [tokens_one, tokens_two, tokens_three, tokens_four, tokens_five, tokens_six, tokens_seven, tokens_eight, tokens_nine]

# %%
# Create a subplot of 3 rows and 3 columns
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Flatten axes for easy iteration
flat_axes = axes.flatten()

# Assuming you have 9 sets of results to plot
for ax, tokens, vectors in zip(flat_axes, token_sets, vector_sets):
    tsne_results = TSNE(n_components=2).fit_transform(vectors)
    ax.scatter(tsne_results[:, 0], tsne_results[:, 1])
    for i, token in enumerate(tokens):
        ax.annotate(token, (tsne_results[i, 0], tsne_results[i, 1]))

axes[0,0].set_title('Wrangle One, Vector Size 100')
axes[0,1].set_title('Wrangle One, Vector Size 200')
axes[0,2].set_title('Wrangle One, Vector Size 300')
axes[1,0].set_title('Wrangle Two, Vector Size 100')
axes[1,1].set_title('Wrangle Two, Vector Size 200')
axes[1,2].set_title('Wrangle Two, Vector Size 300')
axes[2,0].set_title('Wrangle Three, Vector Size 100')
axes[2,1].set_title('Wrangle Three, Vector Size 200')
axes[2,2].set_title('Wrangle Three, Vector Size 300')

# Adjust spacing
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 20))  # Adjust the size as per your need
flat_axes = axes.flatten()

for ax, tokens, vectors in zip(flat_axes, token_sets, vector_sets):
    cos_sim_matrix = cosine_similarity(vectors)
    sns.heatmap(cos_sim_matrix, annot=False, ax=ax)

axes[0,0].set_title('Wrangle One, Vector Size 100')
axes[0,1].set_title('Wrangle One, Vector Size 200')
axes[0,2].set_title('Wrangle One, Vector Size 300')
axes[1,0].set_title('Wrangle Two, Vector Size 100')
axes[1,1].set_title('Wrangle Two, Vector Size 200')
axes[1,2].set_title('Wrangle Two, Vector Size 300')
axes[2,0].set_title('Wrangle Three, Vector Size 100')
axes[2,1].set_title('Wrangle Three, Vector Size 200')
axes[2,2].set_title('Wrangle Three, Vector Size 300')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Text Vectorization using Doc2Vec

# %%
tokens = top_words_three.loc[0:100, 'term'].tolist()

# %%
corpus_one = []
for i, document in enumerate(wrangled_data.loc[:,'wrangle_one']):
    doc = TaggedDocument(words=document,tags=f'Doc{i}')
    corpus_one.append(doc)

corpus_two = []
for i, document in enumerate(wrangled_data.loc[:,'wrangle_two']):
    doc = TaggedDocument(words=document,tags=f'Doc{i}')
    corpus_two.append(doc)

corpus_three = []
for i, document in enumerate(wrangled_data.loc[:,'wrangle_three']):
    doc = TaggedDocument(words=document,tags=f'Doc{i}')
    corpus_three.append(doc)

model_one = Doc2Vec(corpus_one, vector_size=100, window=5, min_count=2, workers=12)
model_two = Doc2Vec(corpus_one, vector_size=200, window=5, min_count=2, workers=12)
model_three = Doc2Vec(corpus_one, vector_size=300, window=5, min_count=2, workers=12)
model_four = Doc2Vec(corpus_two, vector_size=100, window=5, min_count=2, workers=12)
model_five = Doc2Vec(corpus_two, vector_size=200, window=5, min_count=2, workers=12)
model_six = Doc2Vec(corpus_two, vector_size=300, window=5, min_count=2, workers=12)
model_seven = Doc2Vec(corpus_three, vector_size=100, window=5, min_count=2, workers=12)
model_eight = Doc2Vec(corpus_three, vector_size=200, window=5, min_count=2, workers=12)
model_nine = Doc2Vec(corpus_three, vector_size=300, window=5, min_count=2, workers=12)

doc_vectors_one = [model_one.infer_vector(doc.words) for doc in corpus_one]
doc_vectors_two = [model_two.infer_vector(doc.words) for doc in corpus_one]
doc_vectors_three = [model_three.infer_vector(doc.words) for doc in corpus_one]
doc_vectors_four = [model_four.infer_vector(doc.words) for doc in corpus_two]
doc_vectors_five = [model_five.infer_vector(doc.words) for doc in corpus_two]
doc_vectors_six = [model_six.infer_vector(doc.words) for doc in corpus_two]
doc_vectors_seven = [model_seven.infer_vector(doc.words) for doc in corpus_three]
doc_vectors_eight = [model_eight.infer_vector(doc.words) for doc in corpus_three]
doc_vectors_nine = [model_nine.infer_vector(doc.words) for doc in corpus_three]

cosine_similarity_matrix_one = 1 - pairwise_distances(doc_vectors_one, metric="cosine")
cosine_similarity_matrix_two = 1 - pairwise_distances(doc_vectors_two, metric="cosine")
cosine_similarity_matrix_three = 1 - pairwise_distances(doc_vectors_three, metric="cosine")
cosine_similarity_matrix_four = 1 - pairwise_distances(doc_vectors_four, metric="cosine")
cosine_similarity_matrix_five = 1 - pairwise_distances(doc_vectors_five, metric="cosine")
cosine_similarity_matrix_six = 1 - pairwise_distances(doc_vectors_six, metric="cosine")
cosine_similarity_matrix_seven = 1 - pairwise_distances(doc_vectors_seven, metric="cosine")
cosine_similarity_matrix_eight = 1 - pairwise_distances(doc_vectors_eight, metric="cosine")
cosine_similarity_matrix_nine = 1 - pairwise_distances(doc_vectors_nine, metric="cosine")

# %%
doc_vectors_sets = [doc_vectors_one,doc_vectors_two,doc_vectors_three,doc_vectors_four,doc_vectors_five,doc_vectors_six,doc_vectors_seven,doc_vectors_eight,doc_vectors_nine]
cosine_similarity_matrix_sets = [cosine_similarity_matrix_one,cosine_similarity_matrix_two,cosine_similarity_matrix_three,cosine_similarity_matrix_four,cosine_similarity_matrix_five,cosine_similarity_matrix_six,cosine_similarity_matrix_seven,cosine_similarity_matrix_eight,cosine_similarity_matrix_nine]

# %%
# Apply t-SNE to reduce vectors to 2 dimensions
tsne = TSNE(n_components=2, random_state=0)

reduced_vectors_one = tsne.fit_transform(np.array(doc_vectors_one))
reduced_vectors_two = tsne.fit_transform(np.array(doc_vectors_two))
reduced_vectors_three = tsne.fit_transform(np.array(doc_vectors_three))
reduced_vectors_four = tsne.fit_transform(np.array(doc_vectors_four))
reduced_vectors_five = tsne.fit_transform(np.array(doc_vectors_five))
reduced_vectors_six = tsne.fit_transform(np.array(doc_vectors_six))
reduced_vectors_seven = tsne.fit_transform(np.array(doc_vectors_seven))
reduced_vectors_eight = tsne.fit_transform(np.array(doc_vectors_eight))
reduced_vectors_nine = tsne.fit_transform(np.array(doc_vectors_nine))

all_vector_sets = [reduced_vectors_one,reduced_vectors_two,reduced_vectors_three,reduced_vectors_four,reduced_vectors_five,reduced_vectors_six,reduced_vectors_seven,reduced_vectors_eight,reduced_vectors_nine]

# Initialize a 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(17, 17))

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', '#FFA07A', '#8A2BE2', '#7FFF00']


# Loop through all the vector sets and plot them in subplots
for i, vectors in enumerate(all_vector_sets):
    reduced_vectors = tsne.fit_transform(np.array(vectors))
    
    # Determine subplot row and column
    row = i // 3
    col = i % 3
    
    # Scatter plot in the determined subplot
    axs[row, col].scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], marker='o', s=5, edgecolor='k')
    
    # Optionally, annotate points with document ids or titles
    for j, vec in enumerate(reduced_vectors):
        axs[row, col].annotate(str(j), (vec[0], vec[1]), fontsize=8, alpha=0.75)

axs[0,0].set_title('Wrangle One, Vector Size 100')
axs[0,1].set_title('Wrangle One, Vector Size 200')
axs[0,2].set_title('Wrangle One, Vector Size 300')
axs[1,0].set_title('Wrangle Two, Vector Size 100')
axs[1,1].set_title('Wrangle Two, Vector Size 200')
axs[1,2].set_title('Wrangle Two, Vector Size 300')
axs[2,0].set_title('Wrangle Three, Vector Size 100')
axs[2,1].set_title('Wrangle Three, Vector Size 200')
axs[2,2].set_title('Wrangle Three, Vector Size 300')


# Set labels and adjust layout
for ax in axs.flat:
    ax.set(xlabel='t-SNE dimension 1', ylabel='t-SNE dimension 2')
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 15))  # Adjust the size as per your requirement

for i, matrix in enumerate(cosine_similarity_matrix_sets):
    row = i // 3  # Integer division gives us the row number
    col = i % 3   # Remainder gives us the column number
    
    # Create a heatmap in the (row, col) subplot
    sns.heatmap(matrix, annot=False, ax=axs[row, col], cbar=True, xticklabels=False, yticklabels=False)

axs[0,0].set_title('Wrangle One, Vector Size 100')
axs[0,1].set_title('Wrangle One, Vector Size 200')
axs[0,2].set_title('Wrangle One, Vector Size 300')
axs[1,0].set_title('Wrangle Two, Vector Size 100')
axs[1,1].set_title('Wrangle Two, Vector Size 200')
axs[1,2].set_title('Wrangle Two, Vector Size 300')
axs[2,0].set_title('Wrangle Three, Vector Size 100')
axs[2,1].set_title('Wrangle Three, Vector Size 200')
axs[2,2].set_title('Wrangle Three, Vector Size 300')

plt.tight_layout()  # Adjusts subplot params for better layout
plt.show()
